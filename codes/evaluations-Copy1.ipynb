# %%
# %matplotlib inline

# %%
from evaluate_ensemble import *

# %%
milestone3_test()
# Out:
# using feature type bagOfWord
# getting bagOfWord features
# loading existed file data/TrainTest_bagOfWord_81p.npy
# major MNB classifier f1 score micor 0.5285004046710603
# major RBFsvm classifier f1 score micor 0.5195976413458203
# major Polysvm classifier f1 score micor 0.5658457625158978
# major RandomForest classifier f1 score micor 0.4940455543993525
# major ensemble classifier f1 micor 0.559949127066713
# minor MNB classifier f1 score micor 0.3499826569545612
# minor RBFsvm classifier f1 score micor 0.3252399121285698
# minor Polysvm classifier f1 score micor 0.397618221759741
# minor RandomForest classifier f1 score micor 0.3706786911781709
# minor ensemble classifier f1 micor 0.4224765868886576
# ClassifierComparision took time: 25.81 mins
# getting TFIDF features
# loading existed file data/TrainTest_tfidf_35p.npy
# getting TFIDF features
# loading existed file data/TrainTest_tfidf_35p.npy
# ==== Confidence level:   0.0%
# ...
