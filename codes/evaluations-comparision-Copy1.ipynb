# %%
# %matplotlib inline

# %%
from evaluate_ensemble import *

# %%
milestone3_test()
# Out:
# using feature type ngram
# getting ngram features
# loading existed file data/TrainTest_ngram_81p.npy
# major MNB classifier f1 score micor 0.5400624349635795
# major RBFsvm classifier f1 score micor 0.530697190426639
# major Polysvm classifier f1 score micor 0.5701237137241298
# major RandomForest classifier f1 score micor 0.24788992947161523
# major ensemble classifier f1 micor 0.5705861949358307
# minor MNB classifier f1 score micor 0.3692912475430685
# minor RBFsvm classifier f1 score micor 0.3513701005896636
# minor Polysvm classifier f1 score micor 0.41276448144294137
# minor RandomForest classifier f1 score micor 0.12371372412995722
# minor ensemble classifier f1 micor 0.43924153081281075
# ClassifierComparision took time: 39.73 mins
# getting TFIDF features
# loading existed file data/TrainTest_tfidf_35p.npy
# ==== Confidence level:   0.0%
# Number of classified data points (major classes): 1575/1575
# Number of classified data points (minor classes): 1575/1575
# ...
